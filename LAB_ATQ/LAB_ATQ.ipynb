# %% [markdown]
# <a href="https://colab.research.google.com/github/nat1600/AlgorithmsUN2024II/blob/main/LAB_ATQ/LAB_ATQ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Karem Nataly Sierra Molina

# %% [markdown]
# ## Gráfica:

# %% [markdown]
# ![Screen Shot 2025-01-20 at 7.53.41 AM.png](data:image/png;base64,...)

# %% [markdown]
# ## Sharpe Ratio:

# %% [markdown]
# ![Screen Shot 2025-01-20 at 8.07.37 AM.png](data:image/png;base64,...)

# %% [markdown]
# ## ¿Por qué fue elegido el algoritmo?

# %% [markdown]
# `XGBoost` fue elegido porque es un modelo rápido, eficiente y muy preciso. Se destaca por su capacidad de manejar relaciones complejas entre los datos, lo que es muy útil cuando trabajamos con información financiera, que suele ser difícil de predecir.
#
#
# Además, tiene una característica importante: regulariza el modelo, lo que significa que ayuda a evitar que el modelo "aprenda en exceso" detalles innecesarios o ruido en los datos, asegurando que sea más confiable cuando se enfrenta a nuevos datos. También puede manejar grandes cantidades de datos de forma rápida y eficiente, algo clave cuando se trabaja con grandes volúmenes de información financiera.
#
# Por último, XGBoost tiene la capacidad de gestionar automáticamente los datos faltantes, lo que reduce la necesidad de hacer mucho trabajo adicional para limpiar los datos antes de entrenar el modelo.

# %% [markdown]
# ## Variable agregada

# %% [markdown]
# #OBV
# On Balance Volume (OBV) es un indicador que muestra cómo cambia el volumen de transacciones según el precio de un activo. La idea es que el volumen de compras y ventas suele cambiar antes que el precio, por lo que OBV puede ayudar a saber si una tendencia continuará o si está a punto de cambiar.

# %% [markdown]
# Si el precio sube hoy en comparación con ayer, el volumen de transacciones de hoy se suma al OBV. \\
# Si el precio baja, el volumen de hoy se resta del OBV. \\
# Si el precio no cambia, el OBV se mantiene igual.

# %% [markdown]
# ![Screen Shot 2025-01-20 at 8.17.39 AM.png](data:image/png;base64,...)
